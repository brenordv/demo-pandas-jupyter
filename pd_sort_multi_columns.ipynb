# %% [markdown]
# # Loading Sample Data

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/brenordv/data-samples/main/csv/NASA/missionstars.csv", comment="#")

# %%
df.head()
# Out:
#    rowid star_name hip_name    hd_name   gj_name                    tm_name  \
# 0      1   HIP 171  HIP 171  HD 224930  GJ 914 A  2MASS J00021014+2704570 A
# 1      2    HD 142  HIP 522     HD 142  GJ 4.2 A  2MASS J00061921-4904307 A
# 2      3   HIP 544  HIP 544     HD 166      GJ 5    2MASS J00063674+2901175
# 3      4   HIP 677  HIP 677     HD 358       NaN    2MASS J00082326+2905253
# 4      5   HIP 746  HIP 746     HD 432      GJ 8    2MASS J00091071+5908591
#
#    st_exocatflag  st_coronagflag  st_starshadeflag  st_wfirstflag  ...  \
# 0              1               0                 1              0  ...
# 1              1               1                 0              0  ...
# 2              1               0                 1              0  ...
# 3              1               1                 0              0  ...
# 4              1               1                 0              0  ...
#
#    st_wise1lim  st_wise2  st_wise2err st_wise2lim  st_wise3 st_wise3err  \
# ...

# %% [markdown]
# # Sorting multiple columns - all ASCENDING

# %%
df.sort_values(["star_name", "hd_name", "tm_name"])
# Out:
#      rowid star_name    hip_name    hd_name   gj_name  \
# 234    235    14 Her   HIP 79248  HD 145675    GJ 614
# 153    154    47 UMa   HIP 53721   HD 95128    GJ 407
# 342    343    51 Peg  HIP 113357  HD 217014    GJ 882
# 124    125    55 Cnc   HIP 43587   HD 75732  GJ 324 A
# 186    187    61 Vir   HIP 64924  HD 115617    GJ 506
# ..     ...       ...         ...        ...       ...
# 355    356   gam Cep  HIP 116727  HD 222404    GJ 903
# 222    223   iot Dra   HIP 75458  HD 137759       NaN
# 195    196   tau Boo   HIP 67275  HD 120136  GJ 527 A
# 27      28   tau Cet    HIP 8102   HD 10700     GJ 71
# 22      23   ups And    HIP 7513    HD 9826   GJ 61 A
#
#                        tm_name  st_exocatflag  st_coronagflag  \
# 234    2MASS J16102432+4349037              1               1
# 153    2MASS J10592802+4025485              1               1
# 342    2MASS J22572795+2046077              1               0
# 124    2MASS J08523579+2819509              1               1
# ...

# %%
df.sort_values(["star_name", "hd_name", "tm_name"], ascending=True)  # explicitly setting ascending to True, which is the default value.
# Out:
#      rowid star_name    hip_name    hd_name   gj_name  \
# 234    235    14 Her   HIP 79248  HD 145675    GJ 614
# 153    154    47 UMa   HIP 53721   HD 95128    GJ 407
# 342    343    51 Peg  HIP 113357  HD 217014    GJ 882
# 124    125    55 Cnc   HIP 43587   HD 75732  GJ 324 A
# 186    187    61 Vir   HIP 64924  HD 115617    GJ 506
# ..     ...       ...         ...        ...       ...
# 355    356   gam Cep  HIP 116727  HD 222404    GJ 903
# 222    223   iot Dra   HIP 75458  HD 137759       NaN
# 195    196   tau Boo   HIP 67275  HD 120136  GJ 527 A
# 27      28   tau Cet    HIP 8102   HD 10700     GJ 71
# 22      23   ups And    HIP 7513    HD 9826   GJ 61 A
#
#                        tm_name  st_exocatflag  st_coronagflag  \
# 234    2MASS J16102432+4349037              1               1
# 153    2MASS J10592802+4025485              1               1
# 342    2MASS J22572795+2046077              1               0
# 124    2MASS J08523579+2819509              1               1
# ...

# %% [markdown]
# # Sorting multiple columns - all DESCENDING

# %%
df.sort_values(["star_name", "hd_name", "tm_name"], ascending=False)
# Out:
#      rowid star_name    hip_name    hd_name   gj_name  \
# 22      23   ups And    HIP 7513    HD 9826   GJ 61 A
# 27      28   tau Cet    HIP 8102   HD 10700     GJ 71
# 195    196   tau Boo   HIP 67275  HD 120136  GJ 527 A
# 222    223   iot Dra   HIP 75458  HD 137759       NaN
# 355    356   gam Cep  HIP 116727  HD 222404    GJ 903
# ..     ...       ...         ...        ...       ...
# 186    187    61 Vir   HIP 64924  HD 115617    GJ 506
# 124    125    55 Cnc   HIP 43587   HD 75732  GJ 324 A
# 342    343    51 Peg  HIP 113357  HD 217014    GJ 882
# 153    154    47 UMa   HIP 53721   HD 95128    GJ 407
# 234    235    14 Her   HIP 79248  HD 145675    GJ 614
#
#                        tm_name  st_exocatflag  st_coronagflag  \
# 22     2MASS J01364784+4124200              1               1
# 27     2MASS J01440402-1556141              1               1
# 195  2MASS J13471581+1727249 A              1               1
# 222    2MASS J15245578+5857577              0               1
# ...

# %% [markdown]
# # Sorting multiple columns - Some Ascending, some descending

# %%
df.sort_values(
    ["star_name", "hd_name", "tm_name"],
    ascending=[
        False,  # star_name
        True,   # hd_name
        False   # tm_name
    ])
# Out:
#      rowid star_name    hip_name    hd_name   gj_name  \
# 22      23   ups And    HIP 7513    HD 9826   GJ 61 A
# 27      28   tau Cet    HIP 8102   HD 10700     GJ 71
# 195    196   tau Boo   HIP 67275  HD 120136  GJ 527 A
# 222    223   iot Dra   HIP 75458  HD 137759       NaN
# 355    356   gam Cep  HIP 116727  HD 222404    GJ 903
# ..     ...       ...         ...        ...       ...
# 186    187    61 Vir   HIP 64924  HD 115617    GJ 506
# 124    125    55 Cnc   HIP 43587   HD 75732  GJ 324 A
# 342    343    51 Peg  HIP 113357  HD 217014    GJ 882
# 153    154    47 UMa   HIP 53721   HD 95128    GJ 407
# 234    235    14 Her   HIP 79248  HD 145675    GJ 614
#
#                        tm_name  st_exocatflag  st_coronagflag  \
# 22     2MASS J01364784+4124200              1               1
# 27     2MASS J01440402-1556141              1               1
# 195  2MASS J13471581+1727249 A              1               1
# 222    2MASS J15245578+5857577              0               1
# ...
